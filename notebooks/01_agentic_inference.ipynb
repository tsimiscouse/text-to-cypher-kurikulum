# %% [markdown]
# # Agentic Text2Cypher Inference
#
# Notebook ini menjalankan inferensi agentic loop untuk Text2Cypher pipeline.
#
# ## Fitur:
# - Self-correction mechanism dengan maksimal 3 iterasi
# - 9 konfigurasi (3 prompts × 3 schemas)
# - Tracking per-question dan per-iteration

# %%
# Setup path - PENTING: Jalankan cell ini pertama kali!
import sys
import os
from pathlib import Path

# Get the agentic directory (parent of notebooks)
agentic_dir = Path.cwd().parent
project_root = agentic_dir

# Change working directory to agentic folder
os.chdir(agentic_dir)

# Add to Python path
if str(agentic_dir) not in sys.path:
    sys.path.insert(0, str(agentic_dir))

print(f"Working directory: {os.getcwd()}")
print(f"Python path includes: {agentic_dir}")
# Out:
# Working directory: /Users/tsimiscouse/Docs/Sarjana/Skripsi/kg-luthfi/agentic
# Python path includes: /Users/tsimiscouse/Docs/Sarjana/Skripsi/kg-luthfi/agentic

# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv()

import os
print(f"GROQ_API_KEY set: {'Yes' if os.getenv('GROQ_API_KEY') else 'No'}")
print(f"NEO4J_URI set: {'Yes' if os.getenv('NEO4J_URI') else 'No'}")
# Out:
# GROQ_API_KEY set: Yes
# NEO4J_URI set: Yes

# %%
# Reload .env dari direktori agentic
load_dotenv("/Users/tsimiscouse/Docs/Sarjana/Skripsi/kg-luthfi/agentic/.env", override=True)

api_key = os.getenv("GROQ_API_KEY")
print(f"API Key loaded: {api_key[:20]}..." if api_key else "API Key NOT loaded!")
# Out:
# API Key loaded: gsk_3cnZbdKzvw4uXizF...

# %%
# Test Groq API dengan model terbaru
import os
from dotenv import load_dotenv

# Force reload .env
env_path = "/Users/tsimiscouse/Docs/Sarjana/Skripsi/kg-luthfi/agentic/.env"
load_dotenv(env_path, override=True)

api_key = os.getenv("GROQ_API_KEY")
print(f"API Key: {api_key[:20]}...")
print(f"API Key length: {len(api_key) if api_key else 0}")

# Test with OpenAI client (Groq compatible)
from openai import OpenAI

client = OpenAI(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1"
)

# Model updated: qwen-2.5-coder-32b deprecated, using qwen/qwen3-32b
MODEL = "qwen/qwen3-32b"

try:
    response = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": "Say hello in Indonesian"}],
        max_tokens=50
    )
    print(f"Model: {MODEL}")
    print(f"SUCCESS: {response.choices[0].message.content}")
except Exception as e:
    print(f"ERROR: {e}")
# Out:
# API Key: gsk_3cnZbdKzvw4uXizF...
# API Key length: 56
# Model: qwen/qwen3-32b
# SUCCESS: <think>
# Okay, the user asked to say hello in Indonesian. Let me think about how to respond. The most common greeting in Indonesian is "Halo." That's straightforward. But maybe I should consider if there are other greetings too. For example

# %%
# Import modules
from config.settings import Settings
from config.llm_config import LLMConfig
from data.ground_truth_loader import GroundTruthLoader
from prompts.prompt_manager import PromptManager, PromptType, SchemaFormat
from experiment.experiment_runner import ExperimentRunner, run_experiment
from experiment.batch_processor import BatchProcessor

# %% [markdown]
# ## 1. Load Ground Truth Data

# %%
# Load ground truth
loader = GroundTruthLoader()
ground_truth = loader.load()

print(f"Total questions: {len(ground_truth)}")
print(f"\nStatistics:")
stats = loader.get_statistics()
for key, value in stats.items():
    print(f"  {key}: {value}")
# Out:
# Total questions: 52
#
# Statistics:
#   total_items: 52
#   by_complexity: {'Easy': 16, 'Medium': 20, 'Hard': 16}
#   by_reasoning_level: {'Fakta Eksplisit': 16, 'Fakta Implisit': 36}
#   by_sublevel: {'Nodes': 16, 'One-hop': 20, 'Multi-hop': 16}

# %%
# Preview first 5 questions
import pandas as pd

df_preview = pd.DataFrame([item.to_dict() for item in ground_truth[:5]])
df_preview
# Out:
#    id  reasoning_level sublevel complexity  \
# 0   1  Fakta Eksplisit    Nodes       Easy
# 1   2  Fakta Eksplisit    Nodes       Easy
# 2   3  Fakta Eksplisit    Nodes       Easy
# 3   4  Fakta Eksplisit    Nodes       Easy
# 4   5  Fakta Eksplisit    Nodes       Easy
#
#                                             question  \
# 0  Berapakah jumlah SKS untuk mata kuliah 'Aljaba...
# 1  Apakah nama lengkap dari mata kuliah dengan ko...
# 2  Bagaimanakah deskripsi untuk Capaian Lulusan (...
# 3  Tampilkan seluruh mata kuliah yang ditawarkan ...
# 4  Tampilkan nama dan kode untuk semua mata kulia...
#
#                                         cypher_query
# 0  MATCH (n:MK {nama: 'Aljabar Linear'}) RETURN n...
# 1     MATCH (n:MK {kode: 'TKU211131'}) RETURN n.nama
# 2     MATCH (n:SO {kode: 'KP.1'}) RETURN n.deskripsi
# 3    MATCH (n:MK) WHERE n.semester = 1 RETURN n.nama
# 4  MATCH (n:MK) WHERE n.tipe = 'Pilihan' RETURN n...

# %% [markdown]
# ## 2. Test Single Question

# %%
# Initialize components for testing
settings = Settings()
llm_config = LLMConfig()

print(f"Max iterations: {settings.max_iterations}")
print(f"LLM Model: {llm_config.model}")
# Out:
# Max iterations: 3
# LLM Model: qwen/qwen3-32b

# %%
# Test with single question
from experiment.batch_processor import create_batch_processor

processor = create_batch_processor()

# Process first question with Zero-Shot + Full Schema
test_item = ground_truth[0]
print(f"Question: {test_item.question}")
print(f"Ground Truth: {test_item.cypher_query}")
# Out:
# Question: Berapakah jumlah SKS untuk mata kuliah 'Aljabar Linear'?
# Ground Truth: MATCH (n:MK {nama: 'Aljabar Linear'}) RETURN n.sks

# %%
# Run single question
state = processor.process_single(
    item=test_item,
    prompt_type=PromptType.ZERO_SHOT,
    schema_format=SchemaFormat.FULL_SCHEMA
)

print(f"\nResult:")
print(f"  Success: {state.success}")
print(f"  Iterations: {state.total_iterations}")
print(f"  Final Query: {state.final_query}")

processor.close()
# Out:
# Result:
#   Success: True
#   Iterations: 1
#   Final Query: MATCH (m:MK {nama: 'Aljabar Linear'}) RETURN m.sks AS jumlah_sks

# %% [markdown]
# ## 3. Run Single Configuration

# %%
# Run single configuration (e.g., Zero-Shot + Full Schema)
from experiment.experiment_runner import ExperimentRunner

runner = ExperimentRunner()

Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499757, Requested 2801. Please try again in 7m22.0224s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499756, Requested 2808. Please try again in 7m23.0592s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 41: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499756, Requested 2808. Please try again in 7m23.0592s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499755, Requested 2794. Please try again in 7m20.4672s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 42: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499755, Requested 2794. Please try again in 7m20.4672s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499754, Requested 2796. Please try again in 7m20.64s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 43: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499754, Requested 2796. Please try again in 7m20.64s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499754, Requested 2798. Please try again in 7m20.9856s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 44: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499754, Requested 2798. Please try again in 7m20.9856s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499753, Requested 2792. Please try again in 7m19.776s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 45: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499753, Requested 2792. Please try again in 7m19.776s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499752, Requested 2792. Please try again in 7m19.603199999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 46: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499752, Requested 2792. Please try again in 7m19.603199999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499750, Requested 2798. Please try again in 7m20.2944s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 47: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499750, Requested 2798. Please try again in 7m20.2944s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499749, Requested 2810. Please try again in 7m22.1952s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 48: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499749, Requested 2810. Please try again in 7m22.1952s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499748, Requested 2834. Please try again in 7m26.1696s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 49: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499748, Requested 2834. Please try again in 7m26.1696s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499748, Requested 2828. Please try again in 7m25.1328s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 50: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499748, Requested 2828. Please try again in 7m25.1328s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499747, Requested 2813. Please try again in 7m22.368s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 51: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499747, Requested 2813. Please try again in 7m22.368s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:core.llm_client:LLM API error: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499746, Requested 2807. Please try again in 7m21.1584s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ERROR:experiment.experiment_runner:Error processing question 52: Error code: 429 - {'error': {'message': 'Rate limit reached for model `qwen/qwen3-32b` in organization `org_01k7ppxg3ve319gr53jb8nwhj2` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499746, Requested 2807. Please try again in 7m21.1584s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
# Run specific configurations only
specific_configs = [
    (PromptType.ZERO_SHOT, SchemaFormat.FULL_SCHEMA),
    (PromptType.FEW_SHOT, SchemaFormat.FULL_SCHEMA),
    (PromptType.CHAIN_OF_THOUGHT, SchemaFormat.FULL_SCHEMA),
]

# Uncomment to run:
# results = run_experiment(max_questions=5, configurations=specific_configs)

# %% [markdown]
# ## 5. View Results

# %%
# Load saved results
import json

results_path = project_root / "results" / "experiment_summary.json"

if results_path.exists():
    with open(results_path, "r") as f:
        summary = json.load(f)
    
    print(f"Experiment completed at: {summary['timestamp']}")
    print(f"Total configurations: {summary['total_configurations']}")
else:
    print("No results found. Run the experiment first.")
# Out:
# Experiment completed at: 2025-12-30T15:33:39.924275
# Total configurations: 9

# %%
# Display results as DataFrame
if results_path.exists():
    configs = summary.get("configurations", {})
    
    rows = []
    for name, config in configs.items():
        rows.append({
            "Configuration": name,
            "Pass@1 Rate": f"{config['pass_at_1_rate']:.2f}%",
            "KG Valid Rate": f"{config['kg_valid_rate']:.2f}%",
            "LLMetric": f"{config['llmetric']:.2f}",
            "Avg Iterations": f"{config['agentic_metrics']['avg_iterations']:.2f}" if config.get('agentic_metrics') else "N/A",
            "Recovery Rate": f"{config['agentic_metrics']['recovery_rate']*100:.2f}%" if config.get('agentic_metrics') else "N/A",
        })
    
    df_results = pd.DataFrame(rows)
    df_results
